# %% [markdown]
# # **This repo contains links that I find interesting, and which I might reference in the future. It is a mix of diverse blogs and technical articles.**

# %% [markdown]
# ## **My Favorites Tech Blogs**
#
# 1. [Philschmid](https://www.philschmid.de/)
# 2. [Arpit Bhayani](https://arpitbhayani.me/blogs)
# 3. [Leonie Monigatti
# Leonie Monigatti](https://www.leoniemonigatti.com/blog.html)
# 5. [Victoria Lo](https://lo-victoria.com/the-reality-of-writing-consistently-for-2-years-a-personal-story)
# 6. [Sam Who](https://samwho.dev/bloom-filters)
# 7.  [Pradyumna Chippigiri](pradyumnachippigiri.dev/blogs)
# 8.  [Noah Zender on Ideas - incredible values](https://www.noahzender.com/ideas)
# 9.  [CommongClog](https://commoncog.com/three-kinds-of-tacit-knowledge/)
# 10.  [Paras Chopra - Inverted Passion](https://invertedpassion.com/)
#
#
#
#
#
# ## **HTML and CSS**
#
# 1. [CSS Tricks](https://css-tricks.com/)
# 2. [Smashing magazines](https://www.smashingmagazine.com/)

# %% [markdown]
# ## **Software development**
#
# 1. [2026-01-02:How to safely think in systems.](https://lethain.com/how-to-safely-think-in-systems/)
# 2. [Deep Dive Into Modern Web Development](https://fullstackopen.com/en/)
# 3. [Become a machine learning engineer in five to seven steps](https://www.maxmynter.com/pages/blog/become-mle)
# 4. [Learning Containers From The Bottom Up](https://iximiuz.com/en/posts/container-learning-path/)
# 5. [AI-roadmap](https://github.com/Srilochan7/AI-roadmap?tab=readme-ov-file)
# 6. [(General - on documentation and specs)Things I Learnt The Hard Way (in 30 Years of Software Development)](https://blog.juliobiason.me/thoughts/things-i-learnt-the-hard-way/)
# 7. [(General) Everything I know about good system design](https://www.seangoedecke.com/good-system-design/)
# 8. [Contributing to Open Source Pocket Guide By BOLAJI OYEDEJI](https://blog.bolajiayodeji.com/contributing-to-open-source-pocket-guide)
#
#
# ## **Database**
# 1. [Intro to Database Systems by Prof Andy Pavlo](https://www.youtube.com/playlist?list=PLSE8ODhjZXjYMAgsGH-GtY5rJYZ6zjsd5)
# 2. [Design Better Databases: Learn ER Diagrams the Right Way (discussion of one-to-one, many-to-one, many-to-many relationships)](https://sagarshiroya.dev/posts/design-er-diagram-for-database)
# 3. [Database school](https://databaseschool.com/#series)
# 4. [Bloom Filters : The Unsung Hero of System Design by Pradyumna Chippigiri](https://pradyumnachippigiri.dev/blogs/bloom-filters)

# %% [markdown]
# ## **LLM/ML**
#
# ### ***Blogs***
#
#
# 1. [How to Scale Your Model -A Systems View of LLMs on TPUs](https://jax-ml.github.io/scaling-book/)
# 2. [Reward Models](https://cameronrwolfe.substack.com/p/reward-models)
# 3. [Using LLMs for Evaluation](https://cameronrwolfe.substack.com/p/llm-as-a-judge)
# 4. [How to Build Custom Evals for LLMs](https://www.mercity.ai/blog-post/how-to-build-custom-ai-evals-for-llms) - A good write-up on eval
# 5. [How to Use LLM as a Judge (Without Getting Burned by Manthan Gupta)](https://manthanguptaa.in/posts/llm_as_a_judge/)
# 6. [Taxonomical Classification Using Large Language Models](https://www.mercity.ai/blog-post/taxonomical-classification-using-large-language-models/) - A good write-up on using BERT for semantic classification
# 7. [Generating vector embeddings for semantic search locally](https://theconsensus.dev/p/2026/02/15/generating-vector-embeddings-locally.html)
# 8. [Selecting a model for semantic search at Dropbox scale](https://dropbox.tech/machine-learning/selecting-model-semantic-search-dropbox-ai)
# 9. [Deep_Learning_for_Solving_And_Estimating_Dynamic_Economic_Models](https://github.com/sischei/Deep_Learning_for_Solving_And_Estimating_Dynamic_Economic_Models)
#
#
# ### ***Courses***
# 1. [CS336: Language Modeling from Scratch](https://stanford-cs336.github.io/spring2025/)
# 2. [Mathematical Foundations of Machine Learning from IIT](https://www.youtube.com/playlist?list=PLgMDNELGJ1Cay-Q9Cn8KcpUcC58NDWuiu)

# %% [markdown]
# ## **Traditional ML architectures**
#
# 1. [Geometric deep learning](https://geometricdeeplearning.com/blogs/) - A grea source that includes blog, books, on GNN etc
# 2. [Book:Learning Theory from First Principles](https://www.di.ens.fr/~fbach/ltfp_book.pdf)

# %% [markdown]
# ## **RAG and its variants**
#
# 1. [The Hitchhiker's Guide to Vector Search](https://qdrant.tech/blog/hitchhikers-guide/)
# 2. [Everything you need to know about production ready RAG systems : Part 3](https://pradyumnachippigiri.dev/blogs/rag-systems-part3)
# 3. [Everything you need to know about production ready RAG systems : Part 2](https://pradyumnachippigiri.dev/blogs/rag-systems-part2)
# 4. [Everything you need to know about production ready RAG systems : Part 1](https://pradyumnachippigiri.dev/blogs/rag-systems-part1)
#
# ### **GraphRAG**
# 1. [Graph retrieval-augmented generation: A survey](https://dl.acm.org/doi/epdf/10.1145/3777378)
#
#
# ### **Chunking Strategies**
#
# 1. [Chunking Strategies to Improve Your RAG Performance](https://weaviate.io/blog/chunking-strategies-for-rag)
#
#
#
# ### **Embedding models**
#
# 1. [Introducing EmbeddingGemma](https://developers.googleblog.com/en/introducing-embeddinggemma/)
#
#
# ## **Memory**
#
# 1. [I Reverse Engineered ChatGPT's Memory System, and Here's What I Found!](https://manthanguptaa.in/posts/chatgpt_memory/)

# %% [markdown]
# ## **Context Engineering**
#
# 1. [Context Engineering for AI Agents: Lessons from Building Manus](https://manus.im/blog/Context-Engineering-for-AI-Agents-Lessons-from-Building-Manus)

# %% [markdown]
# ## **LLM-related papers**
#
#
#  1. [Neural Turing Machines](https://arxiv.org/pdf/1410.5401)
#  2. [HOW MANY INSTRUCTIONS CAN LLMS FOLLOW AT ONCE?](https://arxiv.org/pdf/2507.11538)
#  3. [Evaluating Parameter Efficient Methods for RLVR](https://www.alphaxiv.org/abs/2512.23165)

# %% [markdown]
# ## **Prompting and Promp Engineering**
#
# 1. [Prompting Is A Design Act](https://www.smashingmagazine.com/2025/08/prompting-design-act-brief-guide-iterate-ai/)

# %% [markdown]
# ## **LLM-based Agents**
#
# ### **Agents Design**
#
# 1. [A practical guide to building agents by OpenAI](https://openai.com/business/guides-and-resources/a-practical-guide-to-building-ai-agents/)
#
# 2. [Agentic Design Patterns](https://docs.google.com/document/d/1rsaK53T3Lg5KoGwvf8ukOUvbELRtH-V0LnOIFDxBryE/edit?)
#
#        -
#    [Chapter 2: Routing](https://docs.google.com/document/d/1ux_n8n3T4bYndOjs1DKW5ccpC802KISdy2IWnlvYbas/edit?)
#
# 3. Course by DeeplearningAI - [Agentic AI](https://www.deeplearning.ai/courses/agentic-ai/)
#
# 4. [Building internal agents](https://lethain.com/agents-series/)
#
# 5. [Web Search for Agents in 2026](https://michaellivs.com/blog/web-search-for-agents-2026/) - Parallel is probebly the best
#
# 6. [Paralle for web search](https://parallel.ai/blog/free-web-search-mcp)
#
#
# ### **Working with agents**
#
# 1. [How to Pair With an Agent](https://ampcode.com/how-to-pair-with-an-agent)
# 2. [Anthropic: Equipping agents for the real world with Agent Skills](https://claude.com/blog/equipping-agents-for-the-real-world-with-agent-skills)
# 3. [OpenAI - Agent skils ](https://developers.openai.com/codex/skills/)
# 4. [Agent Evaluation: A Detailed Guide](https://cameronrwolfe.substack.com/p/agent-evals)
#
#
#
# ### **Papers on agents**
#
# 1. [An Information Theoretic Perspective on Agentic System Design](https://arxiv.org/abs/2512.21720)
# 2. [Towards a Science of Scaling Agent Systems](https://arxiv.org/abs/2512.08296)

# %% [markdown]
# # **Books on my rather**
#
#
#
# 1. [In-Memory Analytics with Apache Arrow: Accelerate data analytics for efficient processing of flat and hierarchical data structures](https://www.amazon.com/Memory-Analytics-Apache-Arrow-hierarchical-ebook/dp/B0CW1BTZFM?ref_=ast_author_dp&th=1&psc=1)
# 2. [A Common-Sense Guide to Data Structures and Algorithms in Python, Volume 1](https://pragprog.com/titles/jwpython/a-common-sense-guide-to-data-structures-and-algorithms-in-python-volume-1/)
# 3. [Python Testing with pytest, Second Edition](https://pragprog.com/titles/bopytest2/python-testing-with-pytest-second-edition/)
# 4. [The Long Game: China's Grand Strategy to Displace American](https://www.amazon.com/Long-Game-Strategy-Displacement-American/dp/0197527914)

# %% [markdown]
# ## Random - Unclassified
#
# 1. [200 Years of American Books for Children](https://files.openhistory.education/pdfs/From_Dr_Mather_to_Dr_Seuss_200_years_of_American_books_--_Lystad,_Mary_H_--_1980_--_Boston_G_K_Hall_--_0816190070_--_8acbc8f8c6ce94a7cd4b014324398f93_1723155631107_0.pdf)
# 2. [Computer Organization and Design: The Hardware/Software Interface](https://shuyuej.com/books/Computer%20Organization%20and%20Design-%20The%20Hardware%3ASoftware%20Interface.pdf)
# 3. [Computer Science from the Bottom Up - A book](https://www.bottomupcs.com/index.html)
# 5. [How to read and remember everything](https://x.com/polymathinvest1/status/2056787808841273652/photo/1)
#
#
# ## Excellent Research Writings
#
# 1. [Deep Research on a Loop: Using AI Agents to Construct Economic Datasets - NBER Research](https://www.nber.org/papers/w35188)
# 2. [Epoch AI](https://epoch.ai/)
# 3. [The Review of Economic Studies](https://www.restud.com/eliciting-multiple-prior-beliefs/)
# 4. [The Paradox of Symmetry](https://www.rcmalternatives.com/2025/02/the-art-of-asymmetric-investing-when-imbalance-beats-balance/)
#
#
#
# ## Excellent blog posts
# 1. [How to walk through walls](https://www.henrikkarlsson.xyz/p/hacker-mindset)
# 2. [Compounding: How Some People Become Unrecognizable](https://www.beautyofsaas.com/p/how-some-people-become-unrecognizable)
# 3. [how to enter side doors](https://velvetnoise.substack.com/p/how-to-enter-side-doors?r=1gcxb&utm_campaign=post&utm_medium=web&triedRedirect=true)
# 4. [Avoiding The Eye of Sauron - On what companies to aim to build for AI](https://blog.southparkcommons.com/p/avoiding-the-eye-of-sauron)
# 5. [Bartosz Ciechanowski on https://ciechanow.ski/internal-combustion-engine/](https://ciechanow.ski/internal-combustion-engine/)
# 6. [Freecodecamp - How to Run an LLM Locally to Interact with Your Documents](https://www.freecodecamp.org/news/author/techno0ptimist/)
# 7. [On the orgin of Effective Altruists by Gradient Ascendant](https://aiascendant.com/p/extropias-children-chapter-5-irrationalism)
# 8. [The Paradox of Symmetry](https://www.rcmalternatives.com/2025/02/the-art-of-asymmetric-investing-when-imbalance-beats-balance/)
# 9. [https://www.governance.ai/research-paper/measuring-ai-agent-autonomy-towards-a-scalable-approach-with-code-inspection]
